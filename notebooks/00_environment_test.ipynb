# %%
# ============================================
# Day 3: Core Libraries Environment Test
# ============================================

# --- NLTK Setup & Test ---
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

from nltk.tokenize import word_tokenize
print("NLTK:", word_tokenize("This is a test sentence."))

# --- spaCy Test ---
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("This is a test sentence.")
print("spaCy tokens:", [token.text for token in doc])

# --- Hugging Face Transformers Test ---
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
print("Transformers:", classifier("I love this internship!"))

# --- Hugging Face Datasets Test ---
from datasets import load_dataset
print("Datasets library imported successfully")

# --- OpenCV Test ---
import cv2
print("OpenCV version:", cv2.__version__)

# --- Torchvision Test ---
import torchvision
print("Torchvision version:", torchvision.__version__)

print("\n✅ All libraries working!")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ARC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ARC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 6
#       2 nltk.download('punkt')
#       3 nltk.download('stopwords')
#       4
#       5 from nltk.tokenize import word_tokenize
# ----> 6 print("NLTK:", word_tokenize("This is a test sentence."))
#       7
#       8 import spacy
#       9 nlp = spacy.load("en_core_web_sm")
#
# File ~\internship-project\venv\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
# ...
